# %% [markdown]
# # Keras深度學習初體驗1
# 利用keras套件，產生一個32個神經元的深度學習模型進行訓練

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

import numpy as np
data = np.random.random((1000, 10)) #隨機產生1000筆資料，每筆資料包含十個float數字
labels = np.random.randint(2, size=(1000, 1)) #隨機產生1000筆資料，每筆資料上限為2(意思就是0 或 1)
print(np.shape(data))
print(data[0])
print(np.shape(labels))
print(labels[0])

model = Sequential()
model.add(Dense(32, activation='relu', input_dim=10))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(data, labels, epochs=10, batch_size=32)

score=model.evaluate(data, labels)
print(score[1])
# Out:
# (1000, 10)
# [0.44672439 0.38231802 0.5198773  0.14155631 0.63928307 0.68496962
#  0.41816146 0.34327474 0.38219838 0.59074249]
# (1000, 1)
# [1]
# Epoch 1/10
# 32/32 [==============================] - 1s 3ms/step - loss: 0.7090 - accuracy: 0.4700
# Epoch 2/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6966 - accuracy: 0.4890
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6941 - accuracy: 0.5230
# Epoch 4/10
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6924 - accuracy: 0.5300
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6915 - accuracy: 0.5380
# Epoch 6/10
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6904 - accuracy: 0.5250
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6886 - accuracy: 0.5430
# Epoch 8/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.5350
# Epoch 9/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6886 - accuracy: 0.5470
# Epoch 10/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6879 - accuracy: 0.5600
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6865 - accuracy: 0.5480
# 0.5479999780654907
