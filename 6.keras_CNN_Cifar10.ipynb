# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
model=Sequential()
model.add(Conv2D(filters=64, kernel_size=(5, 5), input_shape=(32, 32, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=(5, 5), activation='relu'))
model.add(Conv2D(filters=128, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.summary()
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        4864
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        102464
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         204928
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)         409728
#
#  max_pooling2d_1 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 727114 (2.77 MB)
# Trainable params: 727114 (2.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cifar10=keras.datasets.cifar10
(train_data, train_label), (test_data, test_label) = cifar10.load_data()
train_label_original=train_label
train_label = keras.utils.to_categorical(train_label)
test_label = keras.utils.to_categorical(test_label)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
import matplotlib.pyplot as plt
category=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
plt.imshow(train_data[0])
plt.title(category[int(train_label_original[0])])
plt.show()
print(train_label_original[0])
# Out:
# [6]

# %%
train_history=model.fit(train_data,train_label,epochs=30,batch_size=512)
# Out:
# Epoch 1/30
# 98/98 [==============================] - 639s 7s/step - loss: 16.2641 - accuracy: 0.1699
# Epoch 2/30
# 98/98 [==============================] - 628s 6s/step - loss: 2.4454 - accuracy: 0.2055
# Epoch 3/30
# 98/98 [==============================] - 631s 6s/step - loss: 2.0265 - accuracy: 0.3083
# Epoch 4/30
# 98/98 [==============================] - 630s 6s/step - loss: 1.7904 - accuracy: 0.3762
# Epoch 5/30
# 98/98 [==============================] - 632s 6s/step - loss: 1.5852 - accuracy: 0.4496
# Epoch 6/30
# 98/98 [==============================] - 634s 6s/step - loss: 1.4149 - accuracy: 0.5136
# Epoch 7/30
# 98/98 [==============================] - 632s 6s/step - loss: 1.2700 - accuracy: 0.5634
# Epoch 8/30
# 98/98 [==============================] - 635s 6s/step - loss: 1.1659 - accuracy: 0.5999
# Epoch 9/30
# 98/98 [==============================] - 635s 6s/step - loss: 0.9857 - accuracy: 0.6615
# Epoch 10/30
# 98/98 [==============================] - 625s 6s/step - loss: 0.8674 - accuracy: 0.7046
# Epoch 11/30
# 98/98 [==============================] - 622s 6s/step - loss: 0.7871 - accuracy: 0.7346
# Epoch 12/30
# 98/98 [==============================] - 625s 6s/step - loss: 0.6428 - accuracy: 0.7782
# Epoch 13/30
# 98/98 [==============================] - 630s 6s/step - loss: 0.5438 - accuracy: 0.8135
# Epoch 14/30
# 98/98 [==============================] - 628s 6s/step - loss: 0.4663 - accuracy: 0.8459
# Epoch 15/30
# 98/98 [==============================] - 628s 6s/step - loss: 0.4068 - accuracy: 0.8642
# Epoch 16/30
# 98/98 [==============================] - 629s 6s/step - loss: 0.3311 - accuracy: 0.8913
# Epoch 17/30
# 98/98 [==============================] - 625s 6s/step - loss: 0.3296 - accuracy: 0.8956
# Epoch 18/30
# 98/98 [==============================] - 625s 6s/step - loss: 0.2736 - accuracy: 0.9118
# Epoch 19/30
# 98/98 [==============================] - 625s 6s/step - loss: 0.2577 - accuracy: 0.9173
# Epoch 20/30
# 98/98 [==============================] - 621s 6s/step - loss: 0.2620 - accuracy: 0.9222
# Epoch 21/30
# 98/98 [==============================] - 622s 6s/step - loss: 0.2152 - accuracy: 0.9332
# Epoch 22/30
# 98/98 [==============================] - 626s 6s/step - loss: 0.2149 - accuracy: 0.9341
# Epoch 23/30
# 98/98 [==============================] - 623s 6s/step - loss: 0.1990 - accuracy: 0.9389
# Epoch 24/30
# 98/98 [==============================] - 623s 6s/step - loss: 0.1991 - accuracy: 0.9411
# Epoch 25/30
# 98/98 [==============================] - 620s 6s/step - loss: 0.2038 - accuracy: 0.9410
# Epoch 26/30
# 98/98 [==============================] - 624s 6s/step - loss: 0.1972 - accuracy: 0.9445
# Epoch 27/30
# 98/98 [==============================] - 623s 6s/step - loss: 0.1833 - accuracy: 0.9497
# Epoch 28/30
# 98/98 [==============================] - 627s 6s/step - loss: 0.1838 - accuracy: 0.9480
# Epoch 29/30
# 98/98 [==============================] - 627s 6s/step - loss: 0.1741 - accuracy: 0.9505
# Epoch 30/30
# 98/98 [==============================] - 628s 6s/step - loss: 0.1761 - accuracy: 0.9517

# %%
score=model.evaluate(test_data, test_label)
print(score[1])
# Out:
# 313/313 [==============================] - 36s 113ms/step - loss: 3.8627 - accuracy: 0.5889
# 0.5889000296592712

# %%
#繪製正確性與損失歷史圖
import matplotlib.pyplot as plt
import numpy as np

def show_train_history(train_history, train):
    plt.plot(train_history.history[train])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train'], loc='center right')
    plt.show()

show_train_history(train_history, 'accuracy')
show_train_history(train_history, 'loss')
