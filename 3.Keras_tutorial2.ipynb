# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(512, activation='relu', input_dim=784))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

import numpy as np
data = np.random.random((1000, 784))
labels = np.random.randint(10, size=(1000, 10))

model.fit(data, labels, epochs=10, batch_size=32)

score=model.evaluate(data, labels)
print(score[1])
# Out:
# Epoch 1/10
# 32/32 [==============================] - 0s 4ms/step - loss: 346.7492 - accuracy: 0.0940
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 1116.2380 - accuracy: 0.0930
# Epoch 3/10
# 32/32 [==============================] - 0s 4ms/step - loss: 2087.1816 - accuracy: 0.0930
# Epoch 4/10
# 32/32 [==============================] - 0s 4ms/step - loss: 3163.6836 - accuracy: 0.0980
# Epoch 5/10
# 32/32 [==============================] - 0s 4ms/step - loss: 4211.4678 - accuracy: 0.0750
# Epoch 6/10
# 32/32 [==============================] - 0s 4ms/step - loss: 5501.3027 - accuracy: 0.0840
# Epoch 7/10
# 32/32 [==============================] - 0s 4ms/step - loss: 6643.9395 - accuracy: 0.0880
# Epoch 8/10
# 32/32 [==============================] - 0s 4ms/step - loss: 7642.2520 - accuracy: 0.1030
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 8315.1104 - accuracy: 0.1160
# Epoch 10/10
# 32/32 [==============================] - 0s 4ms/step - loss: 9760.3877 - accuracy: 0.0870
# 32/32 [==============================] - 0s 2ms/step - loss: 7653.7539 - accuracy: 0.0600
# 0.05999999865889549
